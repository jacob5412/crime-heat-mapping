# %% [markdown]
# # Extracting named entity from an article

# %%
from bs4 import BeautifulSoup
import requests
import re
from ner_spacy import nlp
from collections import Counter
from spacy import displacy

# https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
#     for script in soup(["script", "style", 'aside']):
#         script.extract()
#     return " ".join(re.split(r'[\n\t]+', soup.get_text()))

    # https://medium.com/@adamaulia/python-simple-crawling-using-beautifulsoup-8247657c2de5
    # find news content
    news_content = soup.find("div",{'class':'description'})
    
    # find paragrapgs in news content
    p = news_content.find_all('p')
    content = ' '.join(item .text for item in p)
    encoded_content = content.encode('utf8','replace')
    news_content = encoded_content.decode("utf-8") 
    
    return news_content

# %%
ny_bb = url_to_string('https://www.indiatoday.in/crime/story/uttar-pradesh-fatehpur-man-kills-wife-mob-beats-death-flee-1615197-2019-11-02')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 24

# %%
# labels of entities
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'GPE': 4, 'DATE': 3, 'PERSON': 8, 'CARDINAL': 4, 'ORG': 5})

# %%
# most frequent tokens
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Qureshi', 4), ('Fatehpur', 2), ('three', 2)]

# %%
# displaying some random token
sentences = [x for x in article.sents]
print(sentences[10])
# Out:
# A doctor, who conducted the post-mortem examination, said that apart from sustaining injuries to his head and mouth, a number of Qureshi's bones were fractured.

# %%
# generating raw mark up - Render a dependency parse tree or named entity visualization
displacy.render(nlp(str(sentences[10])), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">A doctor, who conducted the post-mortem examination, said that apart from sustaining injuries to his head and mouth, a number of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Qureshi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's bones were fractured.</div>

# %%
displacy.render(nlp(str(sentences[10])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="92f7e301a15740bea8406d7ea837af19-0" class="displacy" width="3290" height="677.0" direction="ltr" style="max-width: none; height: 677.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">doctor,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">conducted</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">post-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">mortem</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">examination,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">apart</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">sustaining</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">injuries</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">head</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">mouth,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">number</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">Qureshi</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">bones</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">were</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="587.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">fractured.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-92f7e301a15740bea8406d7ea837af19-0-0" stroke-width="2px" d="M70,542.0 C70,482.0 130.0,482.0 130.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-92f7e301a15740bea8406d7ea837af19-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,544.0 L62,532.0 78,532.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-92f7e301a15740bea8406d7ea837af19-0-1" stroke-width="2px" d="M190,542.0 C190,182.0 995.0,182.0 995.0,542.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-92f7e301a15740bea8406d7ea837af19-0-1" class="displacy-label" startOffset="50%" side="left" fill="cu

# %%
# verbatim, extract part-of-speech and lemmatize
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[10])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('doctor', 'NOUN', 'doctor'),
#  ('conducted', 'VERB', 'conduct'),
#  ('post', 'ADJ', 'post'),
#  ('-', 'ADJ', '-'),
#  ('mortem', 'ADJ', 'mortem'),
#  ('examination', 'NOUN', 'examination'),
#  ('said', 'VERB', 'say'),
#  ('apart', 'ADV', 'apart'),
#  ('sustaining', 'VERB', 'sustain'),
#  ('injuries', 'NOUN', 'injury'),
#  ('head', 'NOUN', 'head'),
#  ('mouth', 'NOUN', 'mouth'),
#  ('number', 'NOUN', 'number'),
#  ('Qureshi', 'PROPN', 'Qureshi'),
#  ('bones', 'NOUN', 'bone'),
#  ('fractured', 'VERB', 'fracture')]

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[10])).ents])
# Out:
# {'Qureshi': 'PERSON'}

# %%
print([(x, x.ent_iob_, x.ent_type_) for x in sentences[10]])
# Out:
# [(A, 'O', ''), (doctor, 'O', ''), (,, 'O', ''), (who, 'O', ''), (conducted, 'O', ''), (the, 'O', ''), (post, 'O', ''), (-, 'O', ''), (mortem, 'O', ''), (examination, 'O', ''), (,, 'O', ''), (said, 'O', ''), (that, 'O', ''), (apart, 'O', ''), (from, 'O', ''), (sustaining, 'O', ''), (injuries, 'O', ''), (to, 'O', ''), (his, 'O', ''), (head, 'O', ''), (and, 'O', ''), (mouth, 'O', ''), (,, 'O', ''), (a, 'O', ''), (number, 'O', ''), (of, 'O', ''), (Qureshi, 'B', 'PERSON'), ('s, 'O', ''), (bones, 'O', ''), (were, 'O', ''), (fractured, 'O', ''), (., 'O', '')]

# %%
article.ents
# Out:
# (Fatehpur,
#  Saturday,
#  Nisar Qureshi's,
#  three,
#  Uttar,
#  Police OP Singh,
#  Amethi,
#  Wednesday,
#  Qureshi,
#  Chhattisgarh,
#  Fatehpur,
#  Afsari,
#  35,
#  Qureshi,
#  DGP,
#  Gazipur Station,
#  Qureshi,
#  Ishfaq,
#  100-150,
#  Friday,
#  Ishfaq,
#  Police Prashant Verma,
#  three,
#  Qureshi)

# %%
displacy.render(article, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">A 40-year-old man was beaten to death by a mob when he was fleeing a village in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fatehpur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  district allegedly after killing his wife with an axe and injuring his in-laws, police said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Saturday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . A purported video of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nisar Qureshi's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  killing was shared widely on social media and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people were arrested after being identified through it, they said.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Uttar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Pradesh Director General of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Police OP Singh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  told reporters in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amethi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  that the incident occurred on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Qureshi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who is from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chhattisgarh
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , was visiting his in-laws' house in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fatehpur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . He killed his wife
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Afsari
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) with an axe and also attacked his sister-in-law and mother-in-law.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Qureshi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was fleeing from the spot when he was caught by locals who thrashed him to death, the official said. The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DGP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said that the incident was being probed and the guilty would be punished.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gazipur Station
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  House Officer Sandeep Tiwari said that
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Qureshi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's brother
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ishfaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  lodged a complaint against
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100-150
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  following which a case was registered. He said that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ishfaq
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  also handed him the video of the incident. Fatehpur Superintendent of
# <mark class="entity" style="background: #7aecec; padding
